# %% [markdown]
# # Homework 01 - ISA Review and RISC-V Introduction
#
# ### Assigned for Spring 2024 Semester: 1/18/2024
# ### Due for Spring 2024 Semester: 1/25/2024 at 11:59pm on Gradescope
#
# > <b>Note:</b> Review the <a href = "https://github.com/mmorri22/cse30321/blob/main/cse30321-syllabus.md">Course Syllabus</a> for policies regarding late submissions for Homework Assignments, as well as homework collaboration. You are welcome to study together, but the final submission must be your own good-faith attempt.

# %% [markdown]
# ## Homework Format Instructions
#
# Compile all your solutions into a single PDF and upload your solutions through the Gradescope submission link. Review the detailed steps for submission at the bottom on this page

# %% [markdown]
# ## Part 1 - Reading and Lecture Review
#
# <b>Problem 1</b> - 40 points - Define and differentiate between Computer Architecture and Computer Organization, and give 4 examples of each.
#
# <b>Problem 2</b> - 20 points - State the basic philosophy of RISC.
#
# <b>Problem 3</b> - 45 points - Briefly describe how each of the following hardware or software components impact performance:
# <ul>
#     <li>Algorithms</li>
#     <li>Programming language, compiler, and architecture</li>
#     <li>Processor and memory system</li>
#     <li>I/O system (hardware and operating system)</li>
# </ul>
#
# <b>Problem 4</b> - 45 points - State and briefly describe <i>in your own words</i> each of the seven Great Ideas in Computer Architecture
#
# <b>Problem 5</b> - 50 points - Consider the following albaCore instructions with time measurements for each stage.
#
# |Instruction Type|IFETCH|DECODE|EXECUTE|DMEM|WRITE BACK|TOTAL|
# |:--|:--|:--|:--|:--|:--|:--|
# |bz|2ns|1ns|2ns|X|X|5ns|
# |ld|2ns|1ns|2ns|3ns|2ns|10ns|
# |add|2ns|1ns|2ns|X|2ns|7ns|
# |st|2ns|1ns|2ns|3ns|X|8ns|
#
# Given four consecutive instructions of <code>bz</code>, <code>ld</code>, <code>add</code>, and <code>sw</code>, calculate the run time for the follow datapath types:
# <ul>
#     <li>Single Cycle datapath</li>
#     <li>Multi Cycle datapath</li>
#     <li>Pipelined datapath</li>
# </ul>

# %% [markdown]
# ## Part 2 - C to albaCore Review
#
# > <b>Note 1:</b> albaCore assembly will not appear on the exams in this class, though will be tested on qualitative differences between albaCore and RISC-V, which we will discuss in detail later this semester.
#
# > <b>Note 2:</b> You are encourages to reference the <a href = "https://github.com/mmorri22/cse30321/blob/main/documents/Practical%20Logic%20and%20Processor%20Design.pdf">Practical Logic and Processor Design</a> textbook from the course page during this assignment. One of the objectives of this assignment is to get you used to referencing the documentation again.

# %% [markdown]
# <b>Problem 6</b> - 100 points - Given <code>x</code> in <code>r1</code>, <code>y</code> in <code>r2</code>, <code>z</code> in <code>r3</code>, and <code>a</code> in <code>r4</code> convert the C code below to albaCore assembly and then albaCore machine encoding. You may use <code>r5</code> and <code>r6</code> for temporary registers if necessary.
#
#     x = 8;
#     y = 5;
#     z = -11;
#     x = y - z;
#     y = x - 5;
#     a = x - y + z;

# %% [markdown]
# <b>Problem 7</b> - 150 points - Given a variable <code>x</code> in memory at address <code>0x77c0</code>, convert the C code to albaCore assembly and then albaCore machine encoding. The address of <code>x</code> is stored in <code>r1</code>, <code>a</code> is in <code>r2</code>, <code>b</code> is in <code>r3</code>, and <code>c</code> is in <code>r4</code>. Use <code>r5</code>, <code>r6</code>, and <code>r7</code> for temp registers if necessary
#
#     int* x = 0xab4e;
#     int a = 7;
#     int b = 3;
#     int c = -9;
#     *x = a – b + c - 5;

# %% [markdown]
# <b>Problem 8</b> - 200 points - Given that <code>x</code> is stored in <code>r1</code>, <code>y</code> is in <code>r2</code>. and <code>z</code> is in <code>r3</code>, convert the C code to albaCore assembly and then albaCore machine encoding. Use <code>r4</code> and <code>r5</code> for temp registers if necessary
#
#     if (x != 8)
#         y = x - z + 5;
#     else
#         y = x + z;

# %% [markdown]
# ## Part 3 - Getting Set Up with RISC-V
#
# In this section of the homework assignment, you will be installing <b><a href = "https://comparch.edu.cvut.cz/qtrvsim/app/">QtRVSim</a></b>, which is an open source RISC-V simulator developed for teaching at Czech Technical University. This tool provides a good visualization of various RISC-V machines.
#
# > The objective of this section is to help you visualize the RISC-V architecture, and gain some familiarity before we study in detailby comparing the architecture visually with what you learned in Logic Design with albaCore.
#
# ### QtRVSim setup:
# <ol>
#     <li>Go to the <a href = "https://github.com/cvut/qtrvsim/releases">QtRVSim GitHub page</a></li>
#     <ul>
#         <li>Go under <b>Assets</b> and select the <code>.zip</code> or <code>.dmg</code> file that corresponds to your Operating System.</li>
#         <li>There is also a WebAssembly version for use in your browser, but this is experimental and may not work well.  It is <b>highly recommended</b> you use the desktop version.</li>
#     </ul>
#     <li>Open QtRVSim</li>
#     <li>Select the “No pipeline no cache” radio button, ensure the checkbox for “Reset at compile time” is checked, and then click “Start empty”.  This will start a new simulation with no program loaded into memory.</li>
#     <li><font color="red"><b>Problem 9</b> - 35 points - Observe the datapath of the RISC-V single cycle datapath that is shown once you start the simulation. Compare the datapath with the albaCore datapath you covered in Logic Design. What are some differences? What are some similarities?</font></li>
#     <li>Click File → Examples → <code>simple-lw-sw-ia.S</code>. This will open a simple example program in the built-in editor.</li>
#     <li>Click the “Compile source and update memory” button, which is near the top and has a blue arrow pointing down. (or click Machine → Compile Source; note the menus list keyboard shortcuts to use)</li>
#     <li>You should now see the Program, Registers, and Memory windows</li>
#     <ul>
#         <li>If at any time a window does not appear, click the Windows menu and then select the missing window (e.g., Windows → Memory).</li>
#     </ul>
#     <li>You can also click Core to see what is going on in the datapath as the program executes.  This is what it should look like now, i.e., before any instructions have been executed:</li>
#     <li>Click the Run button.  By default, this should execute 1 instruction per second.</li>
# </ol>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b>Problem 10</b> - 45 points - Explain what this program does in your own words.  As part of your explanation, include the following information: what are the memory addresses of <code>src_val</code> and <code>dst_val</code> in memory, and how did you find this?

# %% [markdown]
# Now, you will make a change to the example file and re-run the program.  First, save the example file as a new file called <code>HW01_example.s</code>
# <ul><li>click <code>File → Save source as</code> to do this.</li></ul>
#
# Next, replace the <code>beq</code> instruction with a <code>j</code> (jump) pseudoinstruction.  The format of the jump pseudoinstruction is <code>j LABEL</code>. (In my run, the <code>beq</code> instruction was at line 32 and the label was <code>loop</code>. Recompile and run the program and answer the following questions.

# %% [markdown]
# <b>Problem 11</b> - 45 points - Does the program have the same effect?  Specifically, are the results in the “Registers” and “Memory” window the same, or different?

# %% [markdown]
# <b>Problem 12</b> - 45 points - What real instruction is used to implement the j pseudoinstruction?  List the instruction and its operands.  Hint: look at the Program window on the left (specifically, the instruction that replaced the <code>beq</code> instruction) and the <a href = "https://github.com/mmorri22/cse30321/blob/main/documents/RISCVGreenSheet.pdf">RISC-V Reference Data Card</a> to see what instruction is actually being executed.

# %% [markdown]
# <b>Problem 13</b> - 45 points - Explain what the following pragma does:
#
#     #pragma qtrvsim focus memory src_val
#
# Tip: try changing <code>src_val</code> to <code>dst_val</code>, or to <code>0x800</code> to see what happens.  This will be a useful tool in future assignments.

# %% [markdown]
# ## Part 4 - Importing your own code
#
# Finally, implement pseudocode snippet 1 in RISC-V.  Your approach should be the same – 6 instructions, minimally, not counting setup instructions – but you will need to make a number of changes to match the new ISA.
#
# Start with the template_cse30321.S file.
#
# Change the .data section of your code to the following:
#
#     .data
#     .org 0x10
#     i:
#         .word 0x3
#     j:
#         .word 0x6
#     k:
#         .word 0x9
#
# This will place <code>i</code> at <code>0x10</code>, <code>j</code> at <code>0x14</code>, and <code>k</code> at <code>0x18</code>.
#
# > <b>Note:</b> in a 32-bit system, a word is 4 bytes (32 bits).  We typically work with the load word (lw) and store word (sw) instructions which operate on data words, so addresses are specified in multiples of 4.
#
# The first instruction in your program should set x1 to 0x10.  Rather than hardcoding this, use the following instruction to load the address of i into x1:
#
#     la x1, i
#
# Now, implement the data movement in RISC-V assembly, compile, and run your program.  You will include a “before” and “after” screenshot of memory.

# %% [markdown]
# <b>Problem 14</b> - 45 points - Copy the resulting RISC-V assembly language program into your document.
#
# <b>Problem 15</b> - 45 points - Include a screenshot showing the original state of memory, focused on address 0x10
#
# <b>Problem 16</b> - 45 points - Include a screenshot showing the final state of memory, focused on address 0x10

# %% [markdown]
# ## Part 4 - Submission on Gradescope
#
# Upload a single PDF to Gradescope using the following link by the due date on the Canvas <a href = "https://canvas.nd.edu/courses/82217/pages/lecture-notes-and-schedule">Lecture Notes and Schedule page</a>
#
# ### <a href = "">Homework 01 Gradescope Submission Link</a>
#
# You are required to link the Problems with the page where the solution may be found. This requirement is to ensure that that TAs may easily find your answers, so that grades are returned promptly and that errors in grading are prevented.
