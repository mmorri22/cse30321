# %% [markdown]
# # CSE 30321 - Reading 04 - The RISC-V Datapath
#
# ## Spring 2024 Due Date: 2/6/24 - 11:00am

# %% [markdown]
# ### zyBook Reading
#
# Complete the reading and participation activities for the following sections:
# <ul>
# <li>4.1 Introduction</li>
# <li>4.3 Building a Datapath</li>
# <li>4.4 A Simple Implementation Scheme</li>
# </ul>

# %% [markdown]
# > <b>Hint:</b> As you are reading, take brief notes on each of the questions below. These questions serve as the "backbone" of each lecture, so you will be prepared for class discussions. Finally, if you have any confusion or questions regarding a specific topic, make a note and ask in class! This approach is designed to strengthen your proficiency and long-term retention.
#
# ### Class Discussion Questions - Lecture 06
#
# 1. Describe the purpose of each element in the basic datapath in Figure 4.1.1 (We will work together as a class to build the datapath designs)
# ![image.png](attachment:image.png)
# <br></br>
# 2. Define <b>Edge-Triggered Clocking</b>
# <br></br>
# 3. Differentiate between an <b>asserted</b> and <b>deasserted</b> control signal.
# <br></br>
# 4. Describe the purpose of the <b>RegWrite</b> control signal
# <br></br>
# 5. Describe the purpose of the <b>MemRead</b> and <b>MemWrite</b> control signal
# <br></br>
# 6. Describe the purpose of the <b>ALUOp</b> control signal (aka "ALU operation")
# > Hint: This is initially convered in Section 4.3, but is covered in detail in Section 4.4. In Lecture 06, we will briefly describe the ALUOp, but will go into detail in Lecture 07.
# <br></br>
# 7. Describe the purpose of the <b>ALUSrc</b> control signal.
# <br></br>
# 8. Describe the purpose of the <b>Mem2Reg</b> control signal.
# <br></br>
# 9. Describe the purpose of the <b>PCSrc</b> control signal.
# <br></br>
#
# ### Class Discussion Questions - Lecture 07
#
# 1. From Participation Activity 4.3.1, why does the adder which increments the value in the Program Counter register add 4 instead of 1?
# <br></br>
# 2. From Figure 4.3.1, describe how we access the Instruction Memory, including limitations on how the writing to IM, and why we do not need a control signal to IM.
# <br></br>
# 3. From Participation Activity 4.4.1 (Frame 2), describe how <code>Funct7</code>, <code>Funct3</code>, and the <code>Opcode</code> are used to generate the ALUOp signal that goes to the ALU
# <br></br>
# 4. From Participation Activity 4.4.1 (Frame 3), describe how the ALUOp is generated for <code>lw</code> and <code>sw</code> instructions.
# <br></br>
# 5. From Participation Activity 4.4.1 (Frame 4), describe how the ALUOp is generated for a <code>beq</code> instruction.
# <br></br>
# 6. From Participation Activity 4.4.1 (Frame 5), describe how the ALUOp is generated for a <b>R-type</b> instruction.
# > Note: The animation uses AND, but the process for all R-type instructions is the same.
#
# <br></br>
# 7. In your own words, describe why Single Cycle datapaths are not used in modern machines.
# > Note: Look for more justifying detail than just "it's too slow for modern machines." I.e. Which "great ideas" in computer architecture apply here, and how the design of certain instructions (i.e. load instructions, floating points) contribute to these challenges.
